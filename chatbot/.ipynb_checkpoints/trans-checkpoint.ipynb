# %%
import openpyxl
# 한 건의 대화에 대한 정보를 담는 객체입니다.

class Conversation:
    # 질문(Question), 응답(Answer) 두 변수로 구성됩니다.
    def __init__(self, contentName, contentType, question, answer):

        self.contentName = contentName

        self.contentType = contentType

        self.question = question

        self.answer = answer
    def __str__(self):
        return "질문: " + self.question + "\n답변: " + self.answer + "\n"
# 영어 대화 데이터가 담긴 엑셀 파일을 엽니다.
wb = openpyxl.load_workbook('Conversation Data.xlsx')
# 활성 시트를 얻습니다.
ws = wb.active
conversations = []
# 시트 내에 존재하는 모든 영어 대화 데이터를 객체로 담습니다.
for r in ws.rows:
    c = Conversation(r[0].value, r[1].value, r[2].value, r[3].value)
    conversations.append(c)
wb.close()
for c in conversations:
    print(str(c))
# 모든 대화 내용을 출력합니다.
for c in conversations:
    print(str(c))
print('총 ', len(conversations), '개의 대화가 존재합니다.')
# 파일로 출력하기
i = 1
# 출력, 입력 값 JSON 파일을 생성합니다.
prev = str(conversations[0].contentName) + str(conversations[0].contentType)
f = open(prev + '.json', 'w', encoding='UTF-8')
f.write('{ "id": "10d3155d-4468-4118-8f5d-15009af446d0", "name": "' + prev + '", "auto": true, "contexts": [], "responses": [ { "resetContexts": false, "affectedContexts": [], "parameters": [], "messages": [ { "type": 0, "lang": "ko", "speech": "' + conversations[0].answer + '" } ], "defaultResponsePlatforms": {}, "speech": [] } ], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "fallbackIntent": false, "events": [] }')
f.close()
f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')
f.write("[")
f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + conversations[0].question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')
while True:
    if i >= len(conversations):
        f.write("]")
        f.close()
        break;
    c = conversations[i]
    if prev == str(c.contentName) + str(c.contentType):
        f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + c.question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')
    else:
        f.write("]")
        f.close()
        # 출력, 입력 값 JSON 파일을 생성합니다.
        prev = str(c.contentName) + str(c.contentType)
        f = open(prev + '.json', 'w', encoding='UTF-8')
        f.write('{ "id": "10d3155d-4468-4118-8f5d-15009af446d0", "name": "' + prev + '", "auto": true, "contexts": [], "responses": [ { "resetContexts": false, "affectedContexts": [], "parameters": [], "messages": [ { "type": 0, "lang": "ko", "speech": "' + c.answer + '" } ], "defaultResponsePlatforms": {}, "speech": [] } ], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "fallbackIntent": false, "events": [] }')
        f.close()
        f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')
        f.write("[")
        f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + c.question + '", "userDefined": false } ], "isTemplate": false, "count": 0 }')
    i = i + 1
# Out:
# 질문: 주민등록등본 어떻게 때나요
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록등본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 등본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민번호등본 사본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록등본 때는 법
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록등본 발급
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 임대차계약서
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 사본
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 때는 법
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 발급 방법
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 발급
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 중개보수 지출 증빙서류
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 2. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 중개보수 지출
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 3. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 중개보수 지출 증빙
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 4. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비 지출 증빙 서류
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 5. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비 지출 증빙
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 6. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 7. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비 지출
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 8. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비용
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 9. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 통장사본
# 답변: 원하는 통장 은행의 홈페이지에서 증명서 출력하기 ->
#
# 질문: 통장사본 발급
# 답변: 원하는 통장 은행의 홈페이지에서 증명서 출력하기 ->
#
# 질문: 통장사본 출력
# 답변: 원하는 통장 은행의 홈페이지에서 증명서 출력하기 ->
#
# 질문: 주민등록초본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록초본 발급
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록초본 어떻게 때나요
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록초본 어떻게
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 지방세 세목별 미과세 증명서
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 세목별 미과세 증명
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 미과세 증명서
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 미과세 증명서 발급
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 증명서 발급
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 미과세 증명서 발급
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 소득증빙서류
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙서류 발급
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙서류 발급방법
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙서류 뽑기
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 졸업증명서
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 졸업증명서 발급
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 졸업증명서 발급방법
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 졸업증명서 어디서
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 재학증명서
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 재학증명서 발급
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 재학증명서 발급방법
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 재학증명서 어디서
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 중소기업 확인서 사본
# 답변: 중소벤처 24 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 중소기업 확인서
# 답변: 중소벤처 25 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 중소기업 확인서 발급
# 답변: 중소벤처 26 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 중소기업 확인서 발급방법
# 답변: 중소벤처 27 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 공공기관 인증서
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 공공기관 인증서 발급
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 공공기관 확인서 발급
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 공공기관 확인서
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 사업자등록증 사본
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 사업자등록증
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 사업자등록증 발급
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 사업자등록증 발급방법
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 법인등기부등본
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004001.jsp
#
# 질문: 법인등기부등본 발급
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004002.jsp
#
# 질문: 법인등기부등본 발급방법
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004003.jsp
#
# 질문: 법인등기부
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004004.jsp
#
# 질문: 국세.지방세 완납증명서
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 국세 완납 증명서
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 지방세 완납증명서
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 완납증명서 발급
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 고용보험 사업장 취득자 명부
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 고용보험 사업장 취득자
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 고용보홈 사업장 취득자 명부 확인
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 고용보험 사업장 취득자 명부 발급
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 근로계약서
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 6. 연차 유급휴가
#
# 질문: 근로계약서 발급
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 7. 연차 유급휴가
#
# 질문: 근로계약서 발급방법
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 8. 연차 유급휴가
#
# 질문: 근로계약서 어디서
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 9. 연차 유급휴가
#
# 질문: 근로계약서 어떻게
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 10. 연차 유급휴가
#
# 질문: 4대 보험 가입자 명부
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins4/ptl/Main.do
#
# 질문: 4대 보험 가입자 명부 발급
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins5/ptl/Main.do
#
# 질문: 4대 보험 가입자
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins6/ptl/Main.do
#
# 질문: 4대 보험 가입자 명부 발급 방법
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins7/ptl/Main.do
#
# 질문: 봉사실적 확인서
# 답변: 1365 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 봉사실적 확인서 발급
# 답변: 1366 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 봉사실적 확인서 발급 방법
# 답변: 1367 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 봉사실적 확인
# 답변: 1368 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 국민기초생활수급자 증명서
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청_x000D_
# (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 확인
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 증명서 발급
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 증명서 발급 방법
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 확인서
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 장애인증명서
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 장애인증명서 확인
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 장애인증명서 확인서
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 장애인증명서 발급
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 전세보증급반환보증
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000001.jsp
#
# 질문: 전세보증급반환보증 발급
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000002.jsp
#
# 질문: 전세보증급반환보증 발급방법
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000003.jsp
#
# 질문: 전세보증급반환보증 확인
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000004.jsp
#
# 질문: 전세보증급반환보증 확인 방법
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000005.jsp
#
# 질문: 보증료 납부 증빙서류
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 4. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 발급
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 5. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 발급방법
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 6. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 확인
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 7. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 확인 방법
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 8. 계좌이체내역
#
# 질문: 가족관계증명서
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 가족관계증명서 발급
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 가족관계증명서 발급 방법
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 가족관계증명서 확인
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 혼인관계증명서
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=04
#
# 질문: 혼인관계증명서 발급
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=05
#
# 질문: 혼인관계증명서 발급 방법
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=06
#
# 질문: 혼인관계증명서 확인
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=07
#
# 질문: 서울희망 대학 진로 장학금
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 대학 진로 장학금 발급
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 대학 진로 장학금 확인
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문:  서울희망 대학 진로 장학금 발급방법
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울청년정책네트워크
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문:  서울청년정책네트워크 신청
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문: 서울청년정책네트워크 신청 방법
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문: 서울청년정책네트워크 링크
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문: 천호사거리 지하 청년 문화공간 조성
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 천호사거리 지하 청년 문화공간 조성 신청
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 천호사거리 지하 청년 문화공간 조성 발급
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 천호사거리 지하 청년 문화공간 조성 신청 방법
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 서울시 청년부상제대군인지원사업
# 답변: 전화(02-6354-2030~2)로 사전 예약 후 방문
#
# 질문: 서울시 청년부상제대군인지원사업 신청
# 답변: 전화(02-6354-2030~3)로 사전 예약 후 방문
#
# 질문: 서울시 청년부상제대군인지원사업 신청방법
# 답변: 전화(02-6354-2030~4)로 사전 예약 후 방문
#
# 질문: 서울시 청년부상제대군인지원사업 확인
# 답변: 전화(02-6354-2030~5)로 사전 예약 후 방문
#
# 질문: 청년취업사관학교 조성 및 운영
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년취업사관학교 조성 및 운영 신청
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년취업사관학교 조성 및 운영 신청방법
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년취업사관학교 조성 및 운영 확인
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년예술청 운영
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년예술청 운영 신청
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년예술청 운영란
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년예술청 운영 확인
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년 대중교통비 지원 사업
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 청년 대중교통비 지원 사업 신청
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 청년 대중교통비 지원 사업 신청 방법
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 청년 대중교통비 지원 사업 확인
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 지역별 서울청년센터 설치 운영
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj9w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영 신청 방법
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj10w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영 신청
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj11w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영이란
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj12w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영 어디서
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj13w/viewform
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory1=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory2=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory3=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory4=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 미래 청년 일자리
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory1=basic&baCommSelec=true
#
# 질문: 미래 청년 일자리 신청
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory2=basic&baCommSelec=true
#
# 질문: 미래 청년 일자리 신청방법
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory3=basic&baCommSelec=true
#
# 질문: 미래 청년 일자리 확인
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory4=basic&baCommSelec=true
#
# 질문: 서울미래 육성 및 활동 지원 신청
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원 신청방법
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원 이란
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원 어떻게
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원어디서
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울형 뉴딜 일자리 신청
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 서울형 뉴딜 일자리 신청방법
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 서울형 뉴딜 일자리이란
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 서울형 뉴딜 일자리 어떻게
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 독립유공자 후손 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금 신청
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금 신청방법
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금이란
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금 어떻게
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금 신청
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금 신청방법
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금 이란
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금 신청
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금 신청방법
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금이란
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망키움통장
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 서울희망키움통장 신청
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 서울희망키움통장 신청방법
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌 신청
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌 신청방법
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌이란
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 서울시 지역연계형 청년창업 지원사업 넥스트 로컬
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 넥스트 로컬
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 지역연계형 청년창업
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 지원사업
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 노량진 청년 일자리 센터 운영
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 노량진 청년 일자리
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 청년 일자리 센터
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 청년 일자리
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 캠퍼스타운 혁신을 통해 청년희망, 지역경제 활성화
# 답변: (신청링크) -> https://campustown.seoul.go.kr/site/main/university/list\
#
# 질문: 혁신을 통한 청년희망
# 답변: (신청링크) -> https://campustown.seoul.go.kr/site/main/university/list\
#
# 질문: 희망두배 청년 통장
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 청년 통장
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 희망두배 통장
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 두배 통장
# 답변: (신청링크) ->https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래인재 육성 및 활동 지원
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 독립유공자 후손 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 https://www.hissf.or.kr
#
# 질문: 청년저출계좌
# 답변: https://wis.seoul.go.kr/main.do 주민등록상 동주민센터 (가입문의)
#
# 질문: 서울희망키움통장
# 답변: https://wis.seoul.go.kr/main.do 주민등록상 동주민센터 (가입문의)
#
# 질문: 자립준비청년지원
# 답변: 자립준비청년지원 신청방법 : 자립수당 신청서, 금융교육이수증, 보호종료 확인서 https://news.seoul.go.kr/welfare/archives/511982
#
# 질문: 서울시 지역연계형 청년창업 지원사업 넥스트 로컬
# 답변: -http://www.seoulnextlocal.co.kr/ (공고마다 다름)
#
# 질문: 노량진 청년 일자리센터 운영
# 답변: http://youthjob.dongjak.go.kr/
#
# 질문: 캠퍼스타운 혁신을 통해 청년희망, 지역경제 활성화
# 답변: https://campustown.seoul.go.kr/site/main/university/list\
#
# 질문: 희망두배 청년통장
# 답변: https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 가족관계증명서
# 답변: https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=02
#
# 질문: 봉사실적 확인서
# 답변: https://www.1365.go.kr/vols/main.do
#
# 질문: 국민기초생활수급자 증명서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 장애인증명서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 북한이탈주민등록확인서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12500000065
#
# 질문: 전세보증급반환보증 가입보증서
# 답변: https://www.khug.or.kr/hug/web/ig/dr/igdr000002.jsp?tabMenu=Y
#
# 질문: 소득금액증명원
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 지방세 세목별 (미)과세증명서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 혼인관계증명서
# 답변: https://efamily.scourt.go.kr/index.jsp
#
# 질문: 주민등록등본 어떻게 때나요
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록등본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 등본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민번호등본 사본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록등본 때는 법
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록등본 발급
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 임대차계약서
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 사본
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 때는 법
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 발급 방법
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 임대차계약서 발급
# 답변: 인터넷등기소 홈페이지 -> 확정일자 -> 신청하기 (발급링크) -> http://www.iros.go.kr/PMainJ.jsp
#
# 질문: 중개보수 지출 증빙서류
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 2. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 중개보수 지출
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 3. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 중개보수 지출 증빙
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 4. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비 지출 증빙 서류
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 5. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비 지출 증빙
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 6. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 7. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비 지출
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 8. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 이사비용
# 답변: 1. 영수증인 경우 : 이사비용 및 중개보수 납부영수증(카드 영수증, 현금영수증, 세금계산서 등 * 간이영수증 불인정 9. - 계좌이체인 경우 : 계좌이체내역, 이사업체, 공인중개사 사업자등록증 또는 명함 등 이사비 및 중개보수 지출 증빙서류 * 이사 및 중개보수에 소요된 비용임을 객관적으로 증빙할 수 있어야 함 * 중개보수 지출 증빙서류는 중개보수 기재되어 있는 임대차 계약서 사본으로 제출가능
#
# 질문: 통장사본
# 답변: 원하는 통장 은행의 홈페이지에서 증명서 출력하기 ->
#
# 질문: 통장사본 발급
# 답변: 원하는 통장 은행의 홈페이지에서 증명서 출력하기 ->
#
# 질문: 통장사본 출력
# 답변: 원하는 통장 은행의 홈페이지에서 증명서 출력하기 ->
#
# 질문: 주민등록초본
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록초본 발급
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록초본 어떻게 때나요
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 주민등록초본 어떻게
# 답변: 정부 24 주민등록표등본(초본)교부 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000015
#
# 질문: 지방세 세목별 미과세 증명서
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 세목별 미과세 증명
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 미과세 증명서
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 미과세 증명서 발급
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 지방세 증명서 발급
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 미과세 증명서 발급
# 답변: 정부 24 지방세 세목별 과세증명 민원 신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 소득증빙서류
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙서류 발급
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙서류 발급방법
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 소득증빙서류 뽑기
# 답변: 정부 24 소득금액증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 졸업증명서
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 졸업증명서 발급
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 졸업증명서 발급방법
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 졸업증명서 어디서
# 답변: 정부 24 대학교 졸업(예정) 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000009
#
# 질문: 재학증명서
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 재학증명서 발급
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 재학증명서 발급방법
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 재학증명서 어디서
# 답변: 정부 24 대학교 재학 증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=13404000010
#
# 질문: 중소기업 확인서 사본
# 답변: 중소벤처 24 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 중소기업 확인서
# 답변: 중소벤처 25 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 중소기업 확인서 발급
# 답변: 중소벤처 26 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 중소기업 확인서 발급방법
# 답변: 중소벤처 27 중소기업(소상공인)확인서 (발급링크) -> https://www.smes.go.kr/pageApplyCertificateSme
#
# 질문: 공공기관 인증서
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 공공기관 인증서 발급
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 공공기관 확인서 발급
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 공공기관 확인서
# 답변: 행정전사서명 홈페이지 인증서 신청 (발급링크) -> https://gcert.gpki.go.kr/jsp/certInfo/step/issue/searchIssue.jsp
#
# 질문: 사업자등록증 사본
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 사업자등록증
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 사업자등록증 발급
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 사업자등록증 발급방법
# 답변: 정부 24 사업자등록증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000016
#
# 질문: 법인등기부등본
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004001.jsp
#
# 질문: 법인등기부등본 발급
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004002.jsp
#
# 질문: 법인등기부등본 발급방법
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004003.jsp
#
# 질문: 법인등기부
# 답변: 대한민국 법원 인터넷 등기소 법인 열람 후 발급 (발급링크) -> https://www.iros.go.kr/pos1/jsp/help2/jsp/001002004004.jsp
#
# 질문: 국세.지방세 완납증명서
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 국세 완납 증명서
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 지방세 완납증명서
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 완납증명서 발급
# 답변: 정부24 지방세 납세증명 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000056
#
# 질문: 고용보험 사업장 취득자 명부
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 고용보험 사업장 취득자
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 고용보홈 사업장 취득자 명부 확인
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 고용보험 사업장 취득자 명부 발급
# 답변: 고용산재보험 토탈 서비스 홈페이지에서 고용산재보험 사업장 취득자 명부신청 클릭 후 신청 (발급링크) -> https://total.comwel.or.kr
#
# 질문: 근로계약서
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 6. 연차 유급휴가
#
# 질문: 근로계약서 발급
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 7. 연차 유급휴가
#
# 질문: 근로계약서 발급방법
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 8. 연차 유급휴가
#
# 질문: 근로계약서 어디서
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 9. 연차 유급휴가
#
# 질문: 근로계약서 어떻게
# 답변: 필수 기재 사항 1. 임금의 구성항목(급여,상여금,수당 등) 2. 임금 지급방법 3. 임금 계산방법 4. 소정근로시간 5. 주휴일과 공휴적용휴일 10. 연차 유급휴가
#
# 질문: 4대 보험 가입자 명부
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins4/ptl/Main.do
#
# 질문: 4대 보험 가입자 명부 발급
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins5/ptl/Main.do
#
# 질문: 4대 보험 가입자
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins6/ptl/Main.do
#
# 질문: 4대 보험 가입자 명부 발급 방법
# 답변: 4대사회 보험 정보연계센터 접속 후  증명서 발급 -> 가입자 명부 클릭 -> 순서에 따라 진행 (발급링크) -> https://www.4insure.or.kr/ins7/ptl/Main.do
#
# 질문: 봉사실적 확인서
# 답변: 1365 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 봉사실적 확인서 발급
# 답변: 1366 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 봉사실적 확인서 발급 방법
# 답변: 1367 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 봉사실적 확인
# 답변: 1368 자원봉사 포털 로그인 후 확인서 발급 조회 (발급링크) -> https://www.1365.go.kr/vols/P9330/srvcgud/cnfrmnIssu.do
#
# 질문: 국민기초생활수급자 증명서
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청_x000D_
# (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 확인
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 증명서 발급
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 증명서 발급 방법
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 국민기초생활수급자 확인서
# 답변: 정부24 국민기초생활수급자 증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 장애인증명서
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 장애인증명서 확인
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 장애인증명서 확인서
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 장애인증명서 발급
# 답변: 정부24 장애인증명서 발급 민원신청 (발급링크) -> https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 전세보증급반환보증
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000001.jsp
#
# 질문: 전세보증급반환보증 발급
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000002.jsp
#
# 질문: 전세보증급반환보증 발급방법
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000003.jsp
#
# 질문: 전세보증급반환보증 확인
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000004.jsp
#
# 질문: 전세보증급반환보증 확인 방법
# 답변: 주택도시보증공사 홈페이지 전세보증급반환보증 신청 (발급링크) -> https://www.khug.or.kr/hug/web/ig/dr/igdr000005.jsp
#
# 질문: 보증료 납부 증빙서류
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 4. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 발급
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 5. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 발급방법
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 6. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 확인
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 7. 계좌이체내역
#
# 질문: 보증료 납부 증빙서류 확인 방법
# 답변: 1. 전세계약서상 임대인 영수날인 2. 임대인 또는 공인중개사가 발행한 영수증 3. 무통장입금증 8. 계좌이체내역
#
# 질문: 가족관계증명서
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 가족관계증명서 발급
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 가족관계증명서 발급 방법
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 가족관계증명서 확인
# 답변: 정부 24 가족관계등록부 등의 증명서 교부 신청 민원신청 (발급링크) -> https://www.gov.kr/main?a=AA020InfoCappViewApp&CappBizCD=97400000004
#
# 질문: 혼인관계증명서
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=04
#
# 질문: 혼인관계증명서 발급
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=05
#
# 질문: 혼인관계증명서 발급 방법
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=06
#
# 질문: 혼인관계증명서 확인
# 답변: 대한민국 법원 가족관계등록부 신청인 정보 조회 (발급링크) -> https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=07
#
# 질문: 서울희망 대학 진로 장학금
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 대학 진로 장학금 발급
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 대학 진로 장학금 확인
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문:  서울희망 대학 진로 장학금 발급방법
# 답변: (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울청년정책네트워크
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문:  서울청년정책네트워크 신청
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문: 서울청년정책네트워크 신청 방법
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문: 서울청년정책네트워크 링크
# 답변: 온라인 신청 접수 (신청링크) -> https://youth.seoul.go.kr/site/youthnet/home
#
# 질문: 천호사거리 지하 청년 문화공간 조성
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 천호사거리 지하 청년 문화공간 조성 신청
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 천호사거리 지하 청년 문화공간 조성 발급
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 천호사거리 지하 청년 문화공간 조성 신청 방법
# 답변: (신청링크) -> https://news.seoul.go.kr/gov/policy-youthfield
#
# 질문: 서울시 청년부상제대군인지원사업
# 답변: 전화(02-6354-2030~2)로 사전 예약 후 방문
#
# 질문: 서울시 청년부상제대군인지원사업 신청
# 답변: 전화(02-6354-2030~3)로 사전 예약 후 방문
#
# 질문: 서울시 청년부상제대군인지원사업 신청방법
# 답변: 전화(02-6354-2030~4)로 사전 예약 후 방문
#
# 질문: 서울시 청년부상제대군인지원사업 확인
# 답변: 전화(02-6354-2030~5)로 사전 예약 후 방문
#
# 질문: 청년취업사관학교 조성 및 운영
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년취업사관학교 조성 및 운영 신청
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년취업사관학교 조성 및 운영 신청방법
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년취업사관학교 조성 및 운영 확인
# 답변: 홈페이지에서 교육과정별 신청 및 자기소개서 제출 (신청링크) -> https://sesac.seoul.kr/
#
# 질문: 청년예술청 운영
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년예술청 운영 신청
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년예술청 운영란
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년예술청 운영 확인
# 답변: (신청링크) -> http://www.sapy.kr/
#
# 질문: 청년 대중교통비 지원 사업
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 청년 대중교통비 지원 사업 신청
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 청년 대중교통비 지원 사업 신청 방법
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 청년 대중교통비 지원 사업 확인
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/transportationfee_intro
#
# 질문: 지역별 서울청년센터 설치 운영
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj9w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영 신청 방법
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj10w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영 신청
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj11w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영이란
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj12w/viewform
#
# 질문: 지역별 서울청년센터 설치 운영 어디서
# 답변: (신청링크) -> - https://docs.google.com/forms/d/e/1FAIpQLSfN0uhl4Vyh3TP8EESpKvZod7jjCU1oSEBhBYBTlxkHN9Dj13w/viewform
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory1=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory2=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory3=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 청년 쿡비즈니스센터 설치 운영
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34893?cp=1&pageSize=15&sortOrder=BA_REGDATE&sortDirection=DESC&bcId=notice&baCategory4=basic&baNotice=false&baCommSelec=true&baOpenDay=true&baUse=true
#
# 질문: 미래 청년 일자리
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory1=basic&baCommSelec=true
#
# 질문: 미래 청년 일자리 신청
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory2=basic&baCommSelec=true
#
# 질문: 미래 청년 일자리 신청방법
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory3=basic&baCommSelec=true
#
# 질문: 미래 청년 일자리 확인
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/board/notice/34781?baCategory4=basic&baCommSelec=true
#
# 질문: 서울미래 육성 및 활동 지원 신청
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원 신청방법
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원 이란
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원 어떻게
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래 육성 및 활동 지원어디서
# 답변: (신청링크) -> https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울형 뉴딜 일자리 신청
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 서울형 뉴딜 일자리 신청방법
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 서울형 뉴딜 일자리이란
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 서울형 뉴딜 일자리 어떻게
# 답변: (신청링크) -> https://job.seoul.go.kr/www/newdeal/jbhnt_mngr/newDealJbhntMngrWww.do?method=getNewDealMain
#
# 질문: 독립유공자 후손 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금 신청
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금 신청방법
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금이란
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 독립유공자 후손 장학금 어떻게
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금 신청
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금 신청방법
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금 이란
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금 신청
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금 신청방법
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금이란
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 (신청링크) -> https://www.hissf.or.kr
#
# 질문: 서울희망키움통장
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 서울희망키움통장 신청
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 서울희망키움통장 신청방법
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌 신청
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌 신청방법
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 청년저축계좌이란
# 답변: 주민등록상 동주민센터 (가입문의) (신청링크) -> https://wis.seoul.go.kr/main.do
#
# 질문: 서울시 지역연계형 청년창업 지원사업 넥스트 로컬
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 넥스트 로컬
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 지역연계형 청년창업
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 지원사업
# 답변: (신청링크) -> http://www.seoulnextlocal.co.kr/
#
# 질문: 노량진 청년 일자리 센터 운영
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 노량진 청년 일자리
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 청년 일자리 센터
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 청년 일자리
# 답변: (신청링크) -> http://youthjob.dongjak.go.kr/
#
# 질문: 캠퍼스타운 혁신을 통해 청년희망, 지역경제 활성화
# 답변: (신청링크) -> https://campustown.seoul.go.kr/site/main/university/list\
#
# 질문: 혁신을 통한 청년희망
# 답변: (신청링크) -> https://campustown.seoul.go.kr/site/main/university/list\
#
# 질문: 희망두배 청년 통장
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 청년 통장
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 희망두배 통장
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 두배 통장
# 답변: (신청링크) ->https://youth.seoul.go.kr/site/main/content/hr_reg
#
# 질문: 서울미래인재 육성 및 활동 지원
# 답변: (신청링크) -> https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 독립유공자 후손 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 https://www.hissf.or.kr
#
# 질문: 서울우수인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 https://www.hissf.or.kr
#
# 질문: 서울희망 공익인재 장학금
# 답변: 서울장학재단 홈페이지 신청 후 우편 서류 제출 https://www.hissf.or.kr
#
# 질문: 청년저출계좌
# 답변: https://wis.seoul.go.kr/main.do 주민등록상 동주민센터 (가입문의)
#
# 질문: 서울희망키움통장
# 답변: https://wis.seoul.go.kr/main.do 주민등록상 동주민센터 (가입문의)
#
# 질문: 자립준비청년지원
# 답변: 자립준비청년지원 신청방법 : 자립수당 신청서, 금융교육이수증, 보호종료 확인서 https://news.seoul.go.kr/welfare/archives/511982
#
# 질문: 서울시 지역연계형 청년창업 지원사업 넥스트 로컬
# 답변: -http://www.seoulnextlocal.co.kr/ (공고마다 다름)
#
# 질문: 노량진 청년 일자리센터 운영
# 답변: http://youthjob.dongjak.go.kr/
#
# 질문: 캠퍼스타운 혁신을 통해 청년희망, 지역경제 활성화
# 답변: https://campustown.seoul.go.kr/site/main/university/list\
#
# 질문: 희망두배 청년통장
# 답변: https://account.welfare.seoul.kr/web/contents/noticeMatch.lp?srchAct=view&boardCd=20220520111858993941
#
# 질문: 가족관계증명서
# 답변: https://efamily.scourt.go.kr/pt/PtFrrpApplrInfoInqW.do?menuFg=02
#
# 질문: 봉사실적 확인서
# 답변: https://www.1365.go.kr/vols/main.do
#
# 질문: 국민기초생활수급자 증명서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000280
#
# 질문: 장애인증명서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=14600000273
#
# 질문: 북한이탈주민등록확인서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12500000065
#
# 질문: 전세보증급반환보증 가입보증서
# 답변: https://www.khug.or.kr/hug/web/ig/dr/igdr000002.jsp?tabMenu=Y
#
# 질문: 소득금액증명원
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?HighCtgCD=&CappBizCD=12100000021
#
# 질문: 지방세 세목별 (미)과세증명서
# 답변: https://www.gov.kr/mw/AA020InfoCappView.do?CappBizCD=13100000084
#
# 질문: 혼인관계증명서
# 답변: https://efamily.scourt.go.kr/index.jsp
#
# 총  213 개의 대화가 존재합니다.
